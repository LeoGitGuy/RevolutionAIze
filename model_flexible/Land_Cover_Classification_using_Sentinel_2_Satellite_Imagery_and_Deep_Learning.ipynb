# %% [markdown]
# # Land Cover Classification using Deep Learning Techniques and EuroSAT

# %% [markdown]
# ## Mounting google drive for dataset access and saving models

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Libraries

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from PIL import Image
from tqdm import tqdm
from tqdm.notebook import tqdm
import seaborn as sns


from sklearn.metrics import confusion_matrix
from sklearn import model_selection

import torch
import torchvision.models as models
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision.transforms import transforms
from torchvision.utils import make_grid
import torch.nn.functional as F

print("Hello")
# Out:
# Hello

# %%
print(os.getcwd())
# Out:
# /home/studio-lab-user/try-2/Land-Cover-Classification-using-Sentinel-2-Dataset

# %% [markdown]
# ## Config

# %%
ROOT_PATH = '/home/studio-lab-user'

BASE_PATH = os.path.join(ROOT_PATH, 'josh/RevolutionAIze/model/data/2750')    # Here is the original data / images
DATA_PATH = os.path.join(ROOT_PATH, "josh/RevolutionAIze/model/data/2750")    #os.path.join(ROOT_PATH, 'Dataset')
FULL_DATA_DF = os.path.join(ROOT_PATH, 'FULL_DATA.csv')

if not os.path.isdir(DATA_PATH):
    os.mkdir(DATA_PATH)

IDX_CLASS_LABELS = {
    0: 'AnnualCrop',
    1: 'Forest', 
    2: 'HerbaceousVegetation',
    3: 'Highway',
    4: 'Industrial',
    5: 'Pasture',
    6: 'PermanentCrop',
    7: 'Residential',
    8: 'River',
    9: 'SeaLake'
}
CLASSES = ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture','PermanentCrop','Residential','River', 'SeaLake']
CLASS_IDX_LABELS = dict()
for key, val in IDX_CLASS_LABELS.items():
    CLASS_IDX_LABELS[val] = key

NUM_CLASSES = len(IDX_CLASS_LABELS.items())
torch.manual_seed(10)
VALID_SIZE = 0.1

# %% [markdown]
# ## Utils

# %%
## Give idx of each class name
def encode_label(label):
    idx = CLASS_IDX_LABELS[label] 
    return idx

## Take in idx and return the class name
def decode_target(target, text_labels=True):
    result = []
    if text_labels:
        return IDX_CLASS_LABELS[target]
    else:
        return target

## Show batches of images
def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(16, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(images, nrow=16).permute(1, 2, 0))
        break

# %%
## Example for decoding and encoding
print(encode_label('Forest'), decode_target(2))
print(decode_target(2, text_labels=True))
# Out:
# 1 HerbaceousVegetation
# HerbaceousVegetation

# %% [markdown]
# ## Pre-Processing data folders to train and test
# Run this code cells only if you don't have the required dataframe

# %%
from os import walk
i = 0
for (dirpath, dirname, filename) in walk(BASE_PATH):
    print("Directory Path: ", dirpath)
    print("Directory Name: ", dirname)
    print("Filename : ", filename)
    print("----------------------"*10)
    i += 1
    if i > 3:
        break
# Out:
# Directory Path:  /home/studio-lab-user/josh/RevolutionAIze/model/data/2750
# Directory Name:  ['River', 'AnnualCrop', 'HerbaceousVegetation', 'Industrial', 'Residential', 'Highway', 'Pasture', 'Forest', 'SeaLake', 'PermanentCrop']
# Filename :  []
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Directory Path:  /home/studio-lab-user/josh/RevolutionAIze/model/data/2750/River
# Directory Name:  []
# Filename :  ['River_479.jpg', 'River_2178.jpg', 'River_65.jpg', 'River_1643.jpg', 'River_191.jpg', 'River_636.jpg', 'River_2490.jpg', 'River_2337.jpg', 'River_982.jpg', 'River_257.jpg', 'River_1585.jpg', 'River_1222.jpg', 'River_1926.jpg', 'River_1554.jpg', 'River_953.jpg', 'River_521.jpg', 'River_286.jpg', 'River_2441.jpg', 'River_140.jpg', 'River_1135.jpg', 'River_1692.jpg', 'River_2020.jpg', 'River_1470.jpg', 'River_1802.jpg', 'River_405.jpg', 'River_877.jpg', 'River_1011.jpg', 'River_2104.jpg', 'River_19.jpg', 'River_1767.jpg', 'River_712.jpg', 'River_2213.jpg', 'River_373.jpg', 'River_1306.jpg', 'River_1198.jpg', 'River_1528.jpg', 'River_1149.jpg', 'River_870.jpg', 'River_402.jpg', 'River_1805.jpg', 'River_1477.jpg', 'River_1016.jpg', 'River_2103.jpg', 'River_715.jpg', 'River_1760.jpg', 'River_2214.jpg', 'River_1301.jpg', 'River_374.jpg', 'River_1638.jpg', 'River_1259.jpg', 'River_928.jpg', 'River_1288.jpg', 'River_1879.jpg', 'River_769.jpg', 'River_62.jpg', 'River_308.jpg', 'River_2268.jpg', 'River_631.jpg', 'River_196.jpg', 'River_1644.jpg', 'River_2330.jpg', 'River_2497.jpg', 'River_1225.jpg', 'River_1582.jpg', 'River_250.jpg', 'River_985.jpg', 'River_281.jpg', 'River_526.jpg', 'River_954.jpg', 'River_1553.jpg', 'River_1921.jpg', 'River_2446.jpg', 'River_1695.jpg', 'River_1132.jpg', 'River_147.jpg', 'River_2027.jpg', 'River_1479.jpg', 'River_1018.jpg', 'River_10.jpg', 'River_2084.jpg', 'River_1191.jpg', 'River_1636.jpg', 'River_643.jpg', 'River_2342.jpg', 'River_585.jpg', 'River_222.jpg', 'River_1982.jpg', 'River_1257.jpg', 'River_1521.jpg', 'River_1953.jpg', 'River_1286.jpg', 'River_554.jpg', 'River_926.jpg', 'River_2434.jpg', 'River_2393.jpg', 'River_135.jpg', 'River_692.jpg', 'River_1140.jpg', 'River_2055.jpg', 'River_1877.jpg', 'River_1405.jpg', 'River_802.jpg', 'River_470.jpg', 'River_1064.jpg', 'River_2171.jpg', 'River_1712.jpg', 'River_767.jpg', 'River_2266.jpg', 'River_306.jpg', 'River_1373.jpg', 'River_198.jpg', 'River_2499.jpg', 'River_2448.jpg', 'River_528.jpg', 'River_2029.jpg', 'River_149.jpg', 'River_477.jpg', 'River_805.jpg', 'River_1402.jpg', 'River_1870.jpg', 'River_1063.jpg', 'River_2176.jpg', 'River_760.jpg', 'River_1715.jpg', 'River_2261.jpg', 'River_1374.jpg', 'River_301.jpg', 'River_638.jpg', 'River_259.jpg', 'River_2339.jpg', 'River_288.jpg', 'River_1928.jpg', 'River_879.jpg', 'River_1769.jpg', 'River_17.jpg', 'River_1308.jpg', 'River_2083.jpg', 'River_644.jpg', 'River_1631.jpg', 'River_1196.jpg', 'River_2345.jpg', 'River_1250.jpg', 'River_1985.jpg', 'River_225.jpg', 'River_582.jpg', 'River_921.jpg', 'River_553.jpg', 'River_1281.jpg', 'River_1954.jpg', 'River_1526.jpg', 'River_2394.jpg', 'River_2433.jpg', 'River_1147.jpg', 'River_695.jpg', 'River_132.jpg', 'River_2052.jpg', 'River_2254.jpg', 'River_1341.jpg', 'River_1894.jpg', 'River_334.jpg', 'River_493.jpg', 'River_2192.jpg', 'River_755.jpg', 'River_1720.jpg', 'River_1087.jpg', 'River_1056.jpg', 'River_784.jpg', 'River_2143.jpg', 'River_442.jpg', 'River_830.jpg', 'River_1390.jpg', 'River_1437.jpg', 'River_1845.jpg', 'River_2285.jpg', 'River_968.jpg', 'River_1219.jpg', 'River_1678.jpg', 'River_348.jpg', 'River_2228.jpg', 'River_729.jpg', 'River_22.jpg', 'River_399.jpg', 'River_1839.jpg', 'River_1172.jpg', 'River_107.jpg', 'River_2067.jpg', 'River_914.jpg', 'River_566.jpg', 'River_1961.jpg', 'River_1513.jpg', 'River_2406.jpg', 'River_2370.jpg', 'River_1265.jpg', 'River_210.jpg', 'River_671.jpg', 'River_1604.jpg', 'River_25.jpg', 'River_2138.jpg', 'River_439.jpg', 'River_100.jpg', 'River_1175.jpg', 'River_2060.jpg', 'River_1514.jpg', 'River_1966.jpg', 'River_561.jpg', 'River_913.jpg', 'River_2401.jpg', 'River_2377.jpg', 'River_217.jpg', 'River_1262.jpg', 'River_1603.jpg', 'River_676.jpg', 'River_2253.jpg', 'River_494.jpg', 'River_333.jpg', 'River_1893.jpg', 'River_1346.jpg', 'River_2195.jpg', 'River_59.jpg', 'River_1080.jpg', 'River_1727.jpg', 'River_752.jpg', 'River_783.jpg', 'River_1051.jpg', 'River_2144.jpg', 'River_88.jpg', 'River_1842.jpg', ' ...
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Directory Path:  /home/studio-lab-user/josh/RevolutionAIze/model/data/2750/AnnualCrop
# Directory Name:  []
# Filename :  ['AnnualCrop_2053.jpg', 'AnnualCrop_300.jpg', 'AnnualCrop_40.jpg', 'AnnualCrop_1146.jpg', 'AnnualCrop_2432.jpg', 'AnnualCrop_2840.jpg', 'AnnualCrop_2395.jpg', 'AnnualCrop_761.jpg', 'AnnualCrop_1955.jpg', 'AnnualCrop_1527.jpg', 'AnnualCrop_1280.jpg', 'AnnualCrop_1984.jpg', 'AnnualCrop_1251.jpg', 'AnnualCrop_2891.jpg', 'AnnualCrop_2344.jpg', 'AnnualCrop_1197.jpg', 'AnnualCrop_1630.jpg', 'AnnualCrop_91.jpg', 'AnnualCrop_804.jpg', 'AnnualCrop_476.jpg', 'AnnualCrop_2082.jpg', 'AnnualCrop_2725.jpg', 'AnnualCrop_1309.jpg', 'AnnualCrop_289.jpg', 'AnnualCrop_1768.jpg', 'AnnualCrop_258.jpg', 'AnnualCrop_2918.jpg', 'AnnualCrop_639.jpg', 'AnnualCrop_2788.jpg', 'AnnualCrop_1929.jpg', 'AnnualCrop_2338.jpg', 'AnnualCrop_2759.jpg', 'AnnualCrop_878.jpg', 'AnnualCrop_1375.jpg', 'AnnualCrop_694.jpg', 'AnnualCrop_2260.jpg', 'AnnualCrop_133.jpg', 'AnnualCrop_1714.jpg', 'AnnualCrop_2601.jpg', 'AnnualCrop_552.jpg', 'AnnualCrop_920.jpg', 'AnnualCrop_224.jpg', 'AnnualCrop_2177.jpg', 'AnnualCrop_583.jpg', 'AnnualCrop_1062.jpg', 'AnnualCrop_645.jpg', 'AnnualCrop_2964.jpg', 'AnnualCrop_2516.jpg', 'AnnualCrop_1403.jpg', 'AnnualCrop_1871.jpg', 'AnnualCrop_2028.jpg', 'AnnualCrop_2449.jpg', 'AnnualCrop_2498.jpg', 'AnnualCrop_1372.jpg', 'AnnualCrop_134.jpg', 'AnnualCrop_693.jpg', 'AnnualCrop_2267.jpg', 'AnnualCrop_1713.jpg', 'AnnualCrop_927.jpg', 'AnnualCrop_555.jpg', 'AnnualCrop_2606.jpg', 'AnnualCrop_2170.jpg', 'AnnualCrop_584.jpg', 'AnnualCrop_223.jpg', 'AnnualCrop_1065.jpg', 'AnnualCrop_2511.jpg', 'AnnualCrop_2963.jpg', 'AnnualCrop_642.jpg', 'AnnualCrop_1876.jpg', 'AnnualCrop_1404.jpg', 'AnnualCrop_307.jpg', 'AnnualCrop_2054.jpg', 'AnnualCrop_1141.jpg', 'AnnualCrop_47.jpg', 'AnnualCrop_2392.jpg', 'AnnualCrop_766.jpg', 'AnnualCrop_2847.jpg', 'AnnualCrop_2435.jpg', 'AnnualCrop_1287.jpg', 'AnnualCrop_1520.jpg', 'AnnualCrop_1952.jpg', 'AnnualCrop_1256.jpg', 'AnnualCrop_1983.jpg', 'AnnualCrop_2343.jpg', 'AnnualCrop_2896.jpg', 'AnnualCrop_96.jpg', 'AnnualCrop_1637.jpg', 'AnnualCrop_1190.jpg', 'AnnualCrop_2722.jpg', 'AnnualCrop_471.jpg', 'AnnualCrop_803.jpg', 'AnnualCrop_2085.jpg', 'AnnualCrop_148.jpg', 'AnnualCrop_529.jpg', 'AnnualCrop_1019.jpg', 'AnnualCrop_1478.jpg', 'AnnualCrop_199.jpg', 'AnnualCrop_2026.jpg', 'AnnualCrop_375.jpg', 'AnnualCrop_2781.jpg', 'AnnualCrop_35.jpg', 'AnnualCrop_1133.jpg', 'AnnualCrop_1694.jpg', 'AnnualCrop_2835.jpg', 'AnnualCrop_2447.jpg', 'AnnualCrop_714.jpg', 'AnnualCrop_1552.jpg', 'AnnualCrop_1920.jpg', 'AnnualCrop_1583.jpg', 'AnnualCrop_1224.jpg', 'AnnualCrop_2496.jpg', 'AnnualCrop_2331.jpg', 'AnnualCrop_1645.jpg', 'AnnualCrop_403.jpg', 'AnnualCrop_871.jpg', 'AnnualCrop_2750.jpg', 'AnnualCrop_2269.jpg', 'AnnualCrop_929.jpg', 'AnnualCrop_2608.jpg', 'AnnualCrop_1878.jpg', 'AnnualCrop_49.jpg', 'AnnualCrop_309.jpg', 'AnnualCrop_1289.jpg', 'AnnualCrop_768.jpg', 'AnnualCrop_2849.jpg', 'AnnualCrop_2898.jpg', 'AnnualCrop_1258.jpg', 'AnnualCrop_1639.jpg', 'AnnualCrop_98.jpg', 'AnnualCrop_1300.jpg', 'AnnualCrop_2215.jpg', 'AnnualCrop_146.jpg', 'AnnualCrop_1761.jpg', 'AnnualCrop_2674.jpg', 'AnnualCrop_280.jpg', 'AnnualCrop_955.jpg', 'AnnualCrop_527.jpg', 'AnnualCrop_251.jpg', 'AnnualCrop_984.jpg', 'AnnualCrop_2102.jpg', 'AnnualCrop_1017.jpg', 'AnnualCrop_630.jpg', 'AnnualCrop_197.jpg', 'AnnualCrop_2563.jpg', 'AnnualCrop_2911.jpg', 'AnnualCrop_1804.jpg', 'AnnualCrop_1476.jpg', 'AnnualCrop_1148.jpg', 'AnnualCrop_1529.jpg', 'AnnualCrop_478.jpg', 'AnnualCrop_1199.jpg', 'AnnualCrop_1307.jpg', 'AnnualCrop_141.jpg', 'AnnualCrop_2212.jpg', 'AnnualCrop_1766.jpg', 'AnnualCrop_520.jpg', 'AnnualCrop_952.jpg', 'AnnualCrop_2673.jpg', 'AnnualCrop_287.jpg', 'AnnualCrop_983.jpg', 'AnnualCrop_2105.jpg', 'AnnualCrop_256.jpg', 'AnnualCrop_1010.jpg', 'AnnualCrop_190.jpg', 'AnnualCrop_2916.jpg', 'AnnualCrop_2564.jpg', 'AnnualCrop_637.jpg', 'AnnualCrop_1471.jpg', 'AnnualCrop_1803.jpg', 'AnnualCrop_372.jpg', 'AnnualCrop_2786.jpg', 'AnnualCrop_2021.jpg', 'AnnualCrop_1693.jpg', 'AnnualCrop_1134.jpg', 'AnnualCrop_32.jpg', 'AnnualCrop_713.jpg', 'AnnualCro ...
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Directory Path:  /home/studio-lab-user/josh/RevolutionAIze/model/data/2750/HerbaceousVegetation
# Directory Name:  []
# Filename :  ['HerbaceousVegetation_142.jpg', 'HerbaceousVegetation_2829.jpg', 'HerbaceousVegetation_284.jpg', 'HerbaceousVegetation_951.jpg', 'HerbaceousVegetation_523.jpg', 'HerbaceousVegetation_1688.jpg', 'HerbaceousVegetation_1659.jpg', 'HerbaceousVegetation_255.jpg', 'HerbaceousVegetation_980.jpg', 'HerbaceousVegetation_1238.jpg', 'HerbaceousVegetation_634.jpg', 'HerbaceousVegetation_193.jpg', 'HerbaceousVegetation_2614.jpg', 'HerbaceousVegetation_1701.jpg', 'HerbaceousVegetation_75.jpg', 'HerbaceousVegetation_2275.jpg', 'HerbaceousVegetation_1360.jpg', 'HerbaceousVegetation_1416.jpg', 'HerbaceousVegetation_1864.jpg', 'HerbaceousVegetation_2971.jpg', 'HerbaceousVegetation_2503.jpg', 'HerbaceousVegetation_1077.jpg', 'HerbaceousVegetation_2162.jpg', 'HerbaceousVegetation_809.jpg', 'HerbaceousVegetation_1295.jpg', 'HerbaceousVegetation_1940.jpg', 'HerbaceousVegetation_1532.jpg', 'HerbaceousVegetation_699.jpg', 'HerbaceousVegetation_2380.jpg', 'HerbaceousVegetation_2427.jpg', 'HerbaceousVegetation_2855.jpg', 'HerbaceousVegetation_1153.jpg', 'HerbaceousVegetation_2046.jpg', 'HerbaceousVegetation_229.jpg', 'HerbaceousVegetation_2730.jpg', 'HerbaceousVegetation_2097.jpg', 'HerbaceousVegetation_1625.jpg', 'HerbaceousVegetation_1182.jpg', 'HerbaceousVegetation_2351.jpg', 'HerbaceousVegetation_2884.jpg', 'HerbaceousVegetation_648.jpg', 'HerbaceousVegetation_1244.jpg', 'HerbaceousVegetation_1991.jpg', 'HerbaceousVegetation_371.jpg', 'HerbaceousVegetation_2668.jpg', 'HerbaceousVegetation_2209.jpg', 'HerbaceousVegetation_710.jpg', 'HerbaceousVegetation_1818.jpg', 'HerbaceousVegetation_407.jpg', 'HerbaceousVegetation_875.jpg', 'HerbaceousVegetation_1535.jpg', 'HerbaceousVegetation_1947.jpg', 'HerbaceousVegetation_1292.jpg', 'HerbaceousVegetation_2852.jpg', 'HerbaceousVegetation_2420.jpg', 'HerbaceousVegetation_2387.jpg', 'HerbaceousVegetation_139.jpg', 'HerbaceousVegetation_1154.jpg', 'HerbaceousVegetation_558.jpg', 'HerbaceousVegetation_2041.jpg', 'HerbaceousVegetation_2090.jpg', 'HerbaceousVegetation_2737.jpg', 'HerbaceousVegetation_589.jpg', 'HerbaceousVegetation_1185.jpg', 'HerbaceousVegetation_1622.jpg', 'HerbaceousVegetation_2883.jpg', 'HerbaceousVegetation_2356.jpg', 'HerbaceousVegetation_1996.jpg', 'HerbaceousVegetation_1243.jpg', 'HerbaceousVegetation_376.jpg', 'HerbaceousVegetation_717.jpg', 'HerbaceousVegetation_2578.jpg', 'HerbaceousVegetation_872.jpg', 'HerbaceousVegetation_400.jpg', 'HerbaceousVegetation_2119.jpg', 'HerbaceousVegetation_145.jpg', 'HerbaceousVegetation_1549.jpg', 'HerbaceousVegetation_524.jpg', 'HerbaceousVegetation_956.jpg', 'HerbaceousVegetation_283.jpg', 'HerbaceousVegetation_1128.jpg', 'HerbaceousVegetation_987.jpg', 'HerbaceousVegetation_252.jpg', 'HerbaceousVegetation_1598.jpg', 'HerbaceousVegetation_194.jpg', 'HerbaceousVegetation_633.jpg', 'HerbaceousVegetation_2613.jpg', 'HerbaceousVegetation_72.jpg', 'HerbaceousVegetation_690.jpg', 'HerbaceousVegetation_1706.jpg', 'HerbaceousVegetation_2272.jpg', 'HerbaceousVegetation_1367.jpg', 'HerbaceousVegetation_1863.jpg', 'HerbaceousVegetation_1411.jpg', 'HerbaceousVegetation_2504.jpg', 'HerbaceousVegetation_2976.jpg', 'HerbaceousVegetation_1070.jpg', 'HerbaceousVegetation_2165.jpg', 'HerbaceousVegetation_137.jpg', 'HerbaceousVegetation_2389.jpg', 'HerbaceousVegetation_1949.jpg', 'HerbaceousVegetation_556.jpg', 'HerbaceousVegetation_924.jpg', 'HerbaceousVegetation_220.jpg', 'HerbaceousVegetation_587.jpg', 'HerbaceousVegetation_2739.jpg', 'HerbaceousVegetation_1998.jpg', 'HerbaceousVegetation_2358.jpg', 'HerbaceousVegetation_641.jpg', 'HerbaceousVegetation_378.jpg', 'HerbaceousVegetation_2661.jpg', 'HerbaceousVegetation_1774.jpg', 'HerbaceousVegetation_2200.jpg', 'HerbaceousVegetation_719.jpg', 'HerbaceousVegetation_1315.jpg', 'HerbaceousVegetation_1811.jpg', 'HerbaceousVegetation_1463.jpg', 'HerbaceousVegetation_2576.jpg', 'HerbaceousVegetation_2904.jpg', 'HerbaceousVegetation_1002.jpg', 'HerbaceousVegetation_2117.jpg', 'HerbaceousVegetation_1547.jpg', 'Herb ...
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
from os import walk
from tqdm import tqdm

i = 0
DATA_DF = pd.DataFrame(columns = ['image_id', 'label']) 

for (dirpath, dirname, filename) in tqdm(walk(BASE_PATH)):
    for each_file in filename:
        DATA_DF.loc[i] = [each_file, dirpath.split('/')[-1]]
        i += 1
#   # break
DATA_DF.to_csv(FULL_DATA_DF, index=False)
DATA_DF.head()
# Out:
# 11it [00:40,  3.71s/it]
#          image_id  label
# 0   River_479.jpg  River
# 1  River_2178.jpg  River
# 2    River_65.jpg  River
# 3  River_1643.jpg  River
# 4   River_191.jpg  River

# %% [markdown]
# ## Processing data folders to train and test

# %%
DATA_DF = pd.read_csv(FULL_DATA_DF)
DATA_DF = DATA_DF.sample(frac = 1, random_state=48) 
TRAIN_DF = DATA_DF[:-int(len(DATA_DF)*VALID_SIZE)]
VALID_DF = DATA_DF[-int(len(DATA_DF)*VALID_SIZE) :]

# %%
TRAIN_DF.reset_index(inplace = True) 
TRAIN_DF.head()
# Out:
#    index                image_id          label
# 0  19127         Forest_2295.jpg         Forest
# 1   3197      AnnualCrop_777.jpg     AnnualCrop
# 2  24557  PermanentCrop_1924.jpg  PermanentCrop
# 3  17042         Pasture_560.jpg        Pasture
# 4   3697     AnnualCrop_2353.jpg     AnnualCrop

# %%
VALID_DF.reset_index(inplace = True) 
VALID_DF.head()
# Out:
#    index               image_id          label
# 0  21985       SeaLake_1237.jpg        SeaLake
# 1  25621  PermanentCrop_911.jpg  PermanentCrop
# 2  21573       SeaLake_2769.jpg        SeaLake
# 3  25070  PermanentCrop_950.jpg  PermanentCrop
# 4  13947   Residential_2018.jpg    Residential

# %%
TRAIN_DF.size, VALID_DF.size, TRAIN_DF.info
# Out:
# (72900,
#  8100,
#  <bound method DataFrame.info of        index                image_id          label
#  0      19127         Forest_2295.jpg         Forest
#  1       3197      AnnualCrop_777.jpg     AnnualCrop
#  2      24557  PermanentCrop_1924.jpg  PermanentCrop
#  3      17042         Pasture_560.jpg        Pasture
#  4       3697     AnnualCrop_2353.jpg     AnnualCrop
#  ...      ...                     ...            ...
#  24295  26503  PermanentCrop_2153.jpg  PermanentCrop
#  24296  21353         Forest_2050.jpg         Forest
#  24297   9942      Industrial_797.jpg     Industrial
#  24298  19156         Forest_2688.jpg         Forest
#  24299  26963  PermanentCrop_1088.jpg  PermanentCrop
#
#  [24300 rows x 3 columns]>)

# %% [markdown]
# ## Creating Dataset and Dataloaders
#
# Now we will Create custom dataset by extending pytorch Dataset class. We also add provision for adding transformers for data augmentation.

# %%
class EuroSAT(Dataset):
    def __init__(self, train_df, train_dir, transform=None):
        self.train_dir = train_dir
        self.train_df = train_df
        self.transform = transform
        
    def __len__(self):
        return len(self.train_df)
    
    def __getitem__(self, idx):
        row = self.train_df.loc[idx]
        img_id, label = row['image_id'], row['label']
        img = Image.open(os.path.join(self.train_dir, img_id.split('.')[0].split('_')[0], img_id))
        if self.transform:
            img = self.transform(img)
        return img, encode_label(label)

# %% [markdown]
# ### Transformations and Datasets

# %%
## Dataset and transformations
data_transform = transforms.Compose([
                                transforms.Resize(size=(224, 224)),
#                                 transforms.CenterCrop(224),
                                transforms.ToTensor(),
                                # transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                ])
train_ds = EuroSAT(TRAIN_DF, BASE_PATH, data_transform)
valid_ds = EuroSAT(VALID_DF, BASE_PATH, data_transform)
print(len(train_ds), len(valid_ds))
# Out:
# 24300 2700

# %%
## Data loaders and showing batch of data
batch_size = 64
train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=2, pin_memory=True)
valid_dl = DataLoader(valid_ds, batch_size, shuffle=False, num_workers=2, pin_memory=True)
show_batch(train_dl)

# %% [markdown]
# ## Model

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim = 1)
    return torch.tensor(torch.sum(preds==labels).item() / len(preds))

class MulticlassClassifierBase(nn.Module):
    
    def training_step(self, batch):
        img, label = batch
        out = self(img)
        loss = criterion(out, label)
        accu = accuracy(out, label)
        return accu ,loss
    def validation_step(self, batch):
        img, label = batch
        out = self(img)
        loss = criterion(out, label)
        accu = accuracy(out, label)
        return {"val_loss": loss.detach(), "val_acc": accu}
    
    def validation_epoch_ends(self, outputs):
        batch_loss = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_loss).mean()
        batch_acc = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_acc).mean()
        return {"val_loss":epoch_loss.item(), "val_acc":epoch_acc.item()}
    def epoch_end(self, epoch, result):
        print("Epoch [{}],train_accu: {:.4f}, learning_rate: {:.4f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch,result['train_accu'], result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))

# %%
class LULC_Model(MulticlassClassifierBase):
    def __init__(self):
        super().__init__()
        self.network = models.wide_resnet50_2(pretrained=True)
        n_inputs = self.network.fc.in_features
        self.network.fc = nn.Sequential(
                              nn.Linear(n_inputs, 256),
                              nn.ReLU(),
                              nn.Dropout(0.5),
                              nn.Linear(256, NUM_CLASSES),
                              nn.LogSoftmax(dim=1)
                                )
    def forward(self, xb):
        return self.network(xb)
    
    def freeze(self):
        for param in self.network.parameters():
            param.require_grad=False
        for param in self.network.fc.parameters():
            param.require_grad=True
    def unfreeze(self):
        for param in self.network.parameters():
            param.require_grad=True

# %%
model = LULC_Model()
# Out:
# Downloading: "https://download.pytorch.org/models/wide_resnet50_2-95faca4d.pth" to /home/studio-lab-user/.cache/torch/hub/checkpoints/wide_resnet50_2-95faca4d.pth
#   0%|          | 0.00/132M [00:00<?, ?B/s]

# %%
## Running through the data loader => Model => Output
def try_batch(dl):
    for images, labels in dl:  
        print(images.shape)
        out = model(images)
        print(out.shape)
        print(out[0])
        break
try_batch(train_dl)
# Out:
# torch.Size([64, 3, 224, 224])
# torch.Size([64, 10])
# tensor([-2.3386, -2.3923, -2.4215, -2.2125, -2.3511, -1.9580, -2.2238, -2.5246,
#         -2.3968, -2.3208], grad_fn=<SelectBackward0>)

# %% [markdown]
# ## Training and Evaluating

# %%
@torch.no_grad()
def evaluate(model, valid_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in valid_loader]
    return model.validation_epoch_ends(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']
    
def fit(epochs, max_lr,  model, train_loader, valid_loader, weight_decay=0,\
                grad_clip=None,opt_func=torch.optim.SGD, max_epochs_stop=3):
  
    history = []
    valid_loss_min = np.Inf
    valid_acc_max = 0
    model_file_name = 'lulc.pth'
    model_file_name2 = 'lulc_max_acc.pth'
    epochs_no_improve =  0
    optimizer = opt_func(model.parameters(), lr=max_lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.00001)
                         
    for epoch in range(epochs):
        model.train()
        train_loss = []
        train_accu = []
        lrs = []
        for batch in tqdm(train_loader):
            
            accu, loss = model.training_step(batch)
            train_loss.append(loss)
            train_accu.append(accu)
            loss.backward()
            ## Gradient Clipping
            if grad_clip:
                nn.utils.clip_grad_value_(model.parameters(), grad_clip)
            
            optimizer.step()
            optimizer.zero_grad()
            
            lrs.append(get_lr(optimizer))
            
            
            
        result = evaluate(model, valid_loader)
        scheduler.step(result['val_loss'])
        ########### Early Stopping ##############                                         
        valid_loss = result['val_loss']
        valid_acc = result['val_acc']
        if valid_acc > valid_acc_max:
            torch.save(model.state_dict(), model_file_name2)
            valid_acc_max = valid_acc
        if valid_loss<valid_loss_min:
            torch.save(model.state_dict(), model_file_name)
            valid_loss_min = valid_loss                                  
            epochs_no_improve = 0          
        else:
            epochs_no_improve += 1
            if epochs_no_improve > max_epochs_stop:
                result["train_loss"] = torch.stack(train_loss).mean().item()
                result["train_accu"] = torch.stack(train_accu).mean().item()
                result["lrs"] = lrs
                model.epoch_end(epoch, result)
                history.append(result)
                print("Early Stopping............................")
                return history                                
                                                 
        result["train_loss"] = torch.stack(train_loss).mean().item()
        result["train_accu"] = torch.stack(train_accu).mean().item()
        result["lrs"] = lrs
        model.epoch_end(epoch, result)
        history.append(result)
    print("VAL LOSS MIN {}".format(valid_loss_min))
    print("VAL ACC MAX {}".format(valid_acc_max))
    return history

# %% [markdown]
# ## Initializing Device also Loading Data and Model to device¶

# %%
def get_device():
    print(torch.cuda.is_available())
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
def to_device(data, device):
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        for b in self.dl:
            yield to_device(b, self.device)
            
    def __len__(self):
        return len(self.dl)

# %%
# Out:
# cpu

# %%
device = get_device()
## Loading data to devide
train_dl = DeviceDataLoader(train_dl, device)
valid_dl = DeviceDataLoader(valid_dl, device)
## Loading model to device
model = to_device(LULC_Model(), device)
## lets try passing a batch to model again
try_batch(train_dl)
# Out:
# False
# torch.Size([64, 3, 224, 224])
# torch.Size([64, 10])
# tensor([-2.1661, -2.4339, -2.2997, -1.9963, -2.4973, -2.1559, -2.2215, -2.8484,
#         -2.4872, -2.1722], grad_fn=<SelectBackward0>)

# %%
torch.cuda.empty_cache()

# %% [markdown]
# ## Training

# %%
## Hyper Parameters
max_epochs_stop = 10
max_lr = 1e-4
grad_clip = 0.1
weight_decay = 1e-3
batch_size = 64
criterion = nn.CrossEntropyLoss()
epochs = 10
opt_func = torch.optim.Adam
## Evaluating with non-trained model
evaluate(model, valid_dl)
# Out:
# {'val_loss': 2.3044188022613525, 'val_acc': 0.1002907007932663}

# %%
## Freezing except last layer
model.freeze()
## Training
history = fit(epochs, max_lr, model, train_dl, valid_dl, weight_decay, grad_clip, opt_func, max_epochs_stop)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=380.0), HTML(value='')))
# Epoch [0],train_accu: 0.9205, learning_rate: 0.0001, train_loss: 0.2864, val_loss: 0.1155, val_acc: 0.9658
# HBox(children=(FloatProgress(value=0.0, max=380.0), HTML(value='')))
# Epoch [1],train_accu: 0.9657, learning_rate: 0.0001, train_loss: 0.1116, val_loss: 0.1425, val_acc: 0.9535
# HBox(children=(FloatProgress(value=0.0, max=380.0), HTML(value='')))
# Epoch [2],train_accu: 0.9741, learning_rate: 0.0001, train_loss: 0.0873, val_loss: 0.1605, val_acc: 0.9531
# HBox(children=(FloatProgress(value=0.0, max=380.0), HTML(value='')))
# Epoch [3],train_accu: 0.9739, learning_rate: 0.0001, train_loss: 0.0879, val_loss: 0.0783, val_acc: 0.9742
# HBox(children=(FloatProgress(value=0.0, max=380.0), HTML(value='')))
# Epoch [4],train_accu: 0.9792, learning_rate: 0.0001, train_loss: 0.0691, val_loss: 0.1090, val_acc: 0.9677
# HBox(children=(FloatProgress(value=0.0, max=380.0), HTML(value='')))
# Epoch [5],train_accu: 0.9779, learning_rate: 0.0001, train_loss: 0.0709, val_loss: 0.0890, val_acc: 0.9757
# HBox(children=(FloatProgress(value=0.0, max=380.0), HTML(value='')))
# Epoch [6],train_accu: 0.9784, learning_rate: 0.0001, train_loss: 0.0690, val_loss: 0.0853, val_acc: 0.9771
# HBox(children=(FloatProgress(value=0.0, max=380.0), HTML(value='')))
# Epoch [7],train_accu: 0.9837, learning_rate: 0.0000, train_loss: 0.0540, val_loss: 0.0760, val_acc: 0.9800
# HBox(children=(FloatProgress(value=0.0, max=380.0), HTML(value='')))
# Epoch [8],train_accu: 0.9833, learning_rate: 0.0000, train_loss: 0.0559, val_loss: 0.0882, val_acc: 0.9723
# HBox(children=(FloatProgress(value=0.0, max=380.0), HTML(value='')))
# Epoch [9],train_accu: 0.9840, learning_rate: 0.0000, train_loss: 0.0562, val_loss: 0.0789, val_acc: 0.9775
# VAL LOSS MIN 0.0759790912270546
# VAL ACC MAX 0.9800145626068115

# %% [markdown]
# ## Reports

# %% [markdown]
# ### Training Reports

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');
    
plot_losses(history)

# %%
def plot_accuracy(history):
        
    train_accu = [x.get('train_accu') for x in history]
    val_accu = [x['val_acc'] for x in history]
    plt.plot(train_accu, '-bx')
    plt.plot(val_accu, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Training', 'Validation'])
    plt.title('Accuracy vs. No. of epochs');
plot_accuracy(history)

# %%
def plot_lrs(history):
    lrs = np.concatenate([x.get('lrs', []) for x in history])
    plt.plot(lrs)
    plt.xlabel('Batch no.')
    plt.ylabel('Learning rate')
    plt.title('Learning Rate vs. Batch no.');
    
plot_lrs(history)

# %% [markdown]
# ### Prediction Reports

# %%
def show_sample(img, target=None):
    if target:
        print("Label" ,decode_target(int(target), text_labels=True))
    plt.imshow(img.permute(1, 2, 0))

### Predict Single Images
def predict_single(image):
    show_sample(image)
    xb = image.unsqueeze(0)
    xb = to_device(xb, device)
    preds = model(xb)
    _, prediction = torch.max(preds.cpu().detach(), dim=1)
    return decode_target(int(prediction), text_labels=True)

# %%
predict_single(valid_ds[40][0])
# Out:
# 'Highway'

# %%
predict_single(valid_ds[30][0])
# Out:
# 'Industrial'

# %%
predict_single(valid_ds[90][0])
# Out:
# 'Highway'

# %% [markdown]
# ## Evaluation on whole dataset

# %%
batch_size =1
@torch.no_grad()
def predict_dl(dl, model):
    torch.cuda.empty_cache()
    batch_pred, labels = [], []
    for xb, label in tqdm(dl):
        probs = model(xb)
        _, pred = torch.max(probs.cpu().detach(), dim=1)
        batch_pred.append(pred.cpu().detach())     
        labels.append(label)   
    return [x for x in batch_pred], \
            [x for x in labels]

# %%
## Accuracy Evaluation
def final_accuracy(predictions, labels):
  predictions = to_device(predictions, device)
  labels = to_device(labels, device)
  ## Total Accuracy
  total = 0
  for i in range(len(predictions)):
    if predictions[i] == labels[i]:
      total += 1
  acc = total/len(predictions)
  print(acc)

# %%
full_ds = EuroSAT(DATA_DF, BASE_PATH, data_transform)
full_dl = DataLoader(full_ds, batch_size, shuffle=True, num_workers=0, pin_memory=True)
device = get_device()
## Loading data to devide
full_dl = DeviceDataLoader(full_dl, device)
# Out:
# True

# %%
predictions, labels = predict_dl(full_dl, model)
final_accuracy(predictions, labels)
preds = [x.item() for x in predictions]
labs = [x.item() for x in labels]
cm = confusion_matrix(preds, labs)
cm
# Out:
# HBox(children=(FloatProgress(value=0.0, max=27000.0), HTML(value='')))
# 0.9906666666666667
# array([[2943,    0,    0,    0,    1,    1,   13,    0,   11,    0],
#        [   4, 2998,    2,    0,    0,    7,    0,    0,    0,    0],
#        [   0,    0, 2976,    0,    0,    6,   17,    0,    0,    0],
#        [   4,    0,    0, 2499,   12,    0,    3,    1,   45,    0],
#        [   0,    0,    0,    0, 2476,    0,    1,    5,    1,    0],
#        [   5,    1,    7,    0,    0, 1976,    4,    0,    4,    0],
#        [  11,    0,    7,    0,    1,    0, 2460,    0,    1,    0],
#        [   0,    0,    3,    0,    8,    0,    2, 2994,    0,    0],
#        [   2,    0,    1,    1,    2,    0,    0,    0, 2430,    4],
#        [  31,    1,    4,    0,    0,   10,    0,    0,    8, 2996]])

# %%
## Plotting Confusion matrix
df_cm = pd.DataFrame(cm, CLASSES, CLASSES)
sns.set(font_scale=1.4) # for label size
plt.figure(figsize = (16,6))
sns.heatmap(df_cm, annot=True)

# %%
## Evaluation with best validation accuracy model
model = LULC_Model()
model.load_state_dict(torch.load("/content/lulc_max_acc.pth"))
model.eval()
model = to_device(model, device)
predictions, labels = predict_dl(full_dl, model)
final_accuracy(predictions, labels)
preds = [x.item() for x in predictions]
labs = [x.item() for x in labels]
cm = confusion_matrix(preds, labs)
cm
# Out:
# HBox(children=(FloatProgress(value=0.0, max=27000.0), HTML(value='')))
# 0.9912592592592593
# array([[2942,    0,    0,    0,    1,    2,   12,    0,    9,    0],
#        [   4, 2999,    2,    0,    0,    9,    0,    0,    0,    0],
#        [   0,    0, 2983,    0,    0,    7,   17,    0,    0,    0],
#        [   5,    0,    0, 2498,   14,    0,    3,    2,   36,    0],
#        [   0,    0,    0,    0, 2477,    0,    1,    6,    1,    0],
#        [   6,    0,    6,    0,    0, 1972,    4,    0,    2,    0],
#        [  12,    0,    6,    0,    1,    0, 2461,    0,    0,    0],
#        [   0,    0,    0,    0,    3,    0,    2, 2992,    0,    0],
#        [   3,    0,    1,    2,    4,    1,    0,    0, 2444,    4],
#        [  28,    1,    2,    0,    0,    9,    0,    0,    8, 2996]])

# %%
## Plotting Confusion matrix
df_cm = pd.DataFrame(cm, CLASSES, CLASSES)
sns.set(font_scale=1.4) # for label size
plt.figure(figsize = (16,6))
sns.heatmap(df_cm, annot=True)
